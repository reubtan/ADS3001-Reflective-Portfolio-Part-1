# %% [markdown]
# # **Reflective Portfolio Week 1**

# %% [markdown]
# ###**Expectations**
#
# Starting my internship at Keystone, a not-for-profit disability services organisationm, I expected to build a Learning Management System (LMS), however, our first meeting brought a complete change in direction. We were tasked with building the Keystone Employer Database along with an interactive dashboard. Given my background with a similar project in a past internship, I was appointed Project Lead. While stepping back into a leadership role was nerve-wracking and not something I was used to, I felt excited for the challenge.
#
# ###**Execution**
#
# My priority this week was understanding the project scope and breaking it down into manageable components which were the database backend and the interactive dashboard frontend. I proposed using Python’s Dash library for the UI due to its design flexibility and filterable functionality. We also decided as a group to use Excel for the database to balance familiar usability for Keystone with seamless Python integration. One major challenge we discovered after research was that the relevant data seemed hard to get through a traditional scraping method. This would likely be the hardest challenge throughout the project, so we did some surface-level research and found that Google Maps was likely the place with the most reliable data. To organise the team, I let everyone choose their focus area. Mohammed joined me on dashboard development, while Yichang and Rakan were still deciding. Before starting the development of our database and dashboard, our key deliverable for day one was finalising the project brief and roadmap (shown below) to show our supervisor who would then relay it onto Simon.
#
# ###**Next Steps**
# Although Weeks 1 and 2 were allocated for research, our initial groundwork moved so quickly that we are positioned to start preparations and dashboard design ahead of schedule. As Project Lead, I believe the most effective strategy is assigning tasks clearly while trusting my team members to execute their parts independently. This structured workflow will hopefully keep our momentum strong and ensure we stay ahead of milestones.

# %%
from google.colab import files
from PIL import Image
from IPython.display import display

files.upload()
img = Image.open("Keystone Roadmap.png")
display(img.resize((1000, int(img.height * 1000 / img.width))))
# Out:
#      <input type="file" id="files-96c93aec-ad06-4fd0-af2b-999bb2ce69d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96c93aec-ad06-4fd0-af2b-999bb2ce69d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
